# %%
# %matplotlib inline

# %% [markdown]
# # Animated line plot

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from IPython.display import HTML
from math import sin,cos

# %%
def data_gen():
    gen_list = ([cos(t),sin(t)] for t in np.arange(0,1000,0.1))
    return gen_list
 
 
def init():
    ax.set_ylim(-6, 6)
    ax.set_xlim(-6, 6)
    return point
 
fig, ax = plt.subplots()
plt.close()
point, = ax.plot([0], [0], 'go')
point.set_data(0, 0)
ax.grid()
 
def run(data):
 
    t, y = data
    xmin, xmax = ax.get_xlim()
    ymin, ymax = ax.get_ylim()
 
    if t >= xmax:
        ax.set_xlim(xmin, t+1)
#         ax.figure.canvas.draw()
         
    if t <= xmin:
        ax.set_xlim(t-1, xmax)
#         ax.figure.canvas.draw()
         
    if y >= ymax:
        ax.set_ylim(ymin, y+1)
#         ax.figure.canvas.draw()
         
    if y <= ymin:
        ax.set_ylim(y-1, ymax)
#         ax.figure.canvas.draw()
         
    point.set_data(t, y)
     
    return point
 
ani = animation.FuncAnimation(fig, run, data_gen, init_func=init,interval=10)

rc('animation', html='jshtml')
ani
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imge160542693dd442dacfb1b40ccd7bb5f">
#     <br>
#     <input id="_anim_slidere160542693dd442dacfb1b40ccd7bb5f" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anime160542693dd442dacfb1b40ccd7bb5f.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anime160542693dd442dacfb1b40ccd7bb5f.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_selecte160542693dd442dacfb1b40ccd7bb5f" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge160542693dd442dacfb1b40ccd7bb5f";
#     var slider_id = "_anim_slidere160542693dd442dacfb1b40ccd7bb5f";
#     var loop_select_id = "_anim_loop_selecte160542693dd442dacfb1b40ccd7bb5f";
#     var frames = new Array(100);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDMuMC4zLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvnQurowAADoJJREFUeJzt3G2I1nW+x/HvlaNR3pQjYzeLPdhQ\
# FgQxT7LdOesDKRbE0o469aDiBNWTWNsDq91QQRQ4cJZjZc4DjQ3WreEa2wqS6lQOFcwkuVEkp93R\
# B2m10gzOlGESjv/z4NBQYTXTXvab7/R6PfL6M8pnQHz7+1/X/GtVVVUBAMmcVnoAAPwYAgZASgIG\
# QEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZA\
# SgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEqpAvbc\
# c8/FihUrYtWqVdHd3V16DgAFpQnY4OBgbN68Of7yl79ER0dHvPLKK6UnAVBQraqqqvSI0di5c2fs\
# 3r077r///tJTABgH0pzAPvzwwzh27Fjcdtttcf3110dPT0/pSQAU1FR6wFgMDQ3Fo48+Gh9//HHc\
# cMMNsWvXrqjVaif92v7+Iz/xOoD8Wlqml54wamlOYLNmzYqLLroompqa4oILLoipU6fG4cOHS88C\
# oJA0Abviiiuit7c3Tpw4EYODg3H06NGYOXNm6VkAFJLmFuI555wTV111VaxZsyYiIu6555447bQ0\
# /QWgwdJ8CnGsvAcGMHbeAwOAU0zAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnA\
# AEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAA\
# SEnAAEhJwABIKV3Ajh07FsuWLYunn3669BQACkoXsC1btsRZZ51VegYAhaUK2P79+2Pfvn2xdOnS\
# 0lMAKCxVwDZu3BgbNmwoPQOAcSBNwJ555plYuHBhzJkzp/QUAMaBptIDRqu7uzsOHjwY3d3dcejQ\
# oZgyZUqce+65cdlll5WeBkABtaqqqtIjxuqRRx6JX/ziF7Fq1arv/Jr+/iM/4SKAiaGlZXrpCaOW\
# 5hYiAHxdyhPYaDiBAYydExgAnGICBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoC\
# BkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIGQEoCBkBKAgZASgIG\
# QEoCBkBKAgZASk2lB4xFe3t77NmzJ44fPx633nprXHnllaUnAVBImoD19vZGX19fdHZ2xuDgYKxc\
# uVLAAH7G0gRs8eLFsWDBgoiImDFjRnzxxRcxPDwckyZNKrwMgBLSvAc2adKkOPPMMyMioqurK1pb\
# W8UL4GcszQnsKy+//HJ0dXXF448/XnoKAAWlCtjrr78eHR0dsXXr1pg+fXrpOQAUlCZgR44cifb2\
# 9vjTn/4UZ599duk5ABSWJmA7d+6MwcHBWLdu3ci1jRs3xvnnn19wFQCl1KqqqkqPOBX6+4+UngCQ\
# TktLnrdn0nwKEQC+TsAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJ\
# wABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnAAEhJwABIScAASEnA\
# AEipqfSAsXjooYfinXfeiVqtFnfddVcsWLCg9CQACklzAtu9e3d88MEH0dnZGQ8++GA8+OCDpSfB\
# uPbXvq74zVOXxnlbZsZvnro0/trXVXoSNFSaE1hPT08sW7YsIiIuvPDC+PTTT+Pzzz+PadOmFV4G\
# 489f+7ri1v/5j5HX/3t478jrlXP/vdQsaKg0J7CBgYGYOXPmyOvm5ubo7+8vuAj

# %%
# animate over some set of x, y
x = np.linspace(-4, 4, 100)
y = np.sin(x)
# First set up the figure, the axes, and the plot element
fig, ax = plt.subplots()
plt.close()
ax.set_xlim(( -4, 4))
ax.set_ylim((-2, 2))
line1, = ax.plot([], [], lw=2)
line2, = ax.plot([], [], lw=2)
# initialization function: plot the background of each frame
def init():
    line1.set_data(x, y)      
    return (line1,)
# animation function: this is called sequentially
def animate(i):
  at_x = x[i]
  
  # gradient_line will have the form m*x + b
  m = np.cos(at_x)
  b = np.sin(at_x) - np.cos(at_x)*at_x
  gradient_line = m*x + b
  
  line2.set_data(x, gradient_line)
  return (line2,)
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=100, interval=100, blit=True)
rc('animation', html='jshtml')
anim
# Out:
# Output hidden; open in https://colab.research.google.com to view.
